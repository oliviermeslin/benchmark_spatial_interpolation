# %% [markdown]
# # Get Started with MLflow + Scikit-learn
#
# In this guide, we will show you how to train a model with scikit-learn and log your training using MLflow.
#
# We will be using the [Databricks Free Trial](https://mlflow.org/docs/latest/ml/getting-started/databricks-trial.html), which has built-in support for MLflow. The Databricks Free Trial provides an opportunity to use Databricks platform for free. If you haven't already, please register for an account via [this link](https://signup.databricks.com/?destination_url=/ml/experiments-signup?source=OSS_DOCS&dbx_source=TRY_MLFLOW&signup_experience_step=EXPRESS&provider=MLFLOW&utm_source=OSS_DOCS).
#
# You can run code in this guide from cloud-based notebooks like Databricks notebook or Google Colab, or run it on your local machine.

# %% [markdown]
# ## Import dependencies
#
# Let's import the packages

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

import mlflow

# %% [markdown]
# ## Load and prepare the dataset
#
# We will train a simple multi-class classification model for Iris flowers using the [iris dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set).
#
# Let's load the dataset using `load_iris()` into a pandas Dataframe and take a look at the data.

# %%
iris_df = load_iris(as_frame=True).frame
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# Now we'll split our dataset into training and testing sets

# %%
# Split into 80% training and 20% testing
train_df, test_df = train_test_split(iris_df, test_size=0.2, random_state=42)
train_df.shape, test_df.shape
# Out:
# ((120, 5), (30, 5))

# %%
# Separate the target column for the training set
train_dataset = mlflow.data.from_pandas(train_df, name="train")
train_x = train_dataset.df.drop(["target"], axis=1)
train_y = train_dataset.df[["target"]]

train_x.shape, train_y.shape
# Out:
# ((120, 4), (120, 1))

# %%
# Separate the target column for the testing set
test_dataset = mlflow.data.from_pandas(test_df, name="test")
test_x = test_dataset.df.drop(["target"], axis=1)
test_y = test_dataset.df[["target"]]

test_x.shape, test_y.shape
# Out:
# ((30, 4), (30, 1))

# %% [markdown]
# ## Define the Model
#
# For this example, we'll use an ElasticNet model with some pre-defined hyperparameters. Let's also define a helper function to compute some metrics to evaluate our model's performance.

# %%
lr = ElasticNet(alpha=0.5, l1_ratio=0.5, random_state=42)

# %%
def compute_metrics(actual, predicted):
    rmse = mean_squared_error(actual, predicted)
    mae = mean_absolute_error(actual, predicted)
    r2 = r2_score(actual, predicted)

    return rmse, mae, r2

# %% [markdown]
# ## Connect to MLflow Tracking Server
#
# On SSP Cloud, the connection to the MLFlow Tracking Server is automatically configured at start time 1/ if the MLFlow service was started before Jupyter or VSCode; 2/ if the MLFlow service is run in the same namespace as the VSCode/Jupyter service. Here, we are gonna use a _shared_ MLFlow service located on the `benchmark-spatial-interpolation` namespace, so we need to configure the connection to the Tracking Server. Two things to set up:
# - `mlflow.set_tracking_uri`: the URI to the Tracking Server.
# - `mlflow.set_experiment`: pick up a name you like, preferably a meaningful one.

# %%
mlflow.set_tracking_uri("https://projet-benchmark-spatial-interpolation-mlflow.user.lab.sspcloud.fr/")

# %%
mlflow.set_experiment("mlflow-sklearn-quickstart")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 mlflow.set_experiment("mlflow-sklearn-quickstart")
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:187, in set_experiment(experiment_name, experiment_id)
#     185 with _experiment_lock:
#     186     if experiment_id is None:
# --> 187         experiment = client.get_experiment_by_name(experiment_name)
#     188         if not experiment:
#     189             _logger.info(
#     190                 "Experiment with name '%s' does not exist. Creating a new experiment.",
#     191                 experiment_name,
#     192             )
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:280, in TrackingServiceClient.get_experiment_by_name(self, name)
#     272 def get_experiment_by_name(self, name):
#     273     """
#     274     Args:
#     275         name: The experiment name.
#    (...)    278         :py:class:`mlflow.entities.Experiment`
#     279     """
# --> 280     return self.store.get_experiment_by_name(name)
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:865, in RestStore.get_experiment_by_name(self, experiment_name)
#     863 try:
#     864     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 865     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     866     return Experiment.from_proto(response_proto.experiment)
#     867 except MlflowException as e:
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:203, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     201     endpoint, method = self._METHOD_TO_INFO[api]
#     202 response_proto = response_proto or api.Response()
# --> 203 return call_endpoint(
#     204     self.get_host_creds(),
#     205     endpoint,
#     206     method,
#     207     json_body,
#     208     response_proto,
#     209     retry_timeout_seconds=retry_timeout_seconds,
#     210 )
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:321, in verify_rest_response(response, endpoint)
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
# --> 321         raise MlflowException(
#     322             f"{base_msg}. Response body: '{response.text}'",
#     323             error_code=get_error_code(response.status_code),
#     324         )
#     326 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     327 # response
#     328 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/experiments/get-by-name failed with error code 401 != 200. Response body: 'You are not authenticated. Please see https://www.mlflow.org/docs/latest/auth/index.html#authenticating-to-mlflow on how to authenticate.'

# %% [markdown]
# ## Logging with MLflow
#
# MLflow has powerful tracking APIs that let's us log runs and models along with their associated metadata such as parameters and metrics. Let's first start a training run to train our model.

# %%
# Start a training run
with mlflow.start_run() as training_run:
    # Log the parameters for our model
    mlflow.log_param("alpha", 0.5)
    mlflow.log_param("l1_ratio", 0.5)

    # Train and log our model, which inherits the parameters
    lr.fit(train_x, train_y)
    model_info = mlflow.sklearn.log_model(sk_model=lr, name="elasticnet", input_example=train_x)

    # Evaluate the model on the training dataset and log metrics
    # These metrics will be linked to both the model and run
    predictions = lr.predict(train_x)
    (rmse, mae, r2) = compute_metrics(train_y, predictions)
    mlflow.log_metrics(
        metrics={
            "rmse": rmse,
            "r2": r2,
            "mae": mae,
        },
        dataset=train_dataset,
    )
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Start a training run
# ----> 2 with mlflow.start_run() as training_run:
#       3     # Log the parameters for our model
#       4     mlflow.log_param("alpha", 0.5)
#       5     mlflow.log_param("l1_ratio", 0.5)
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:478, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     474         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     476     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 478     active_run_obj = client.create_run(
#     479         experiment_id=exp_id_for_run,
#     480         tags=resolved_tags,
#     481         run_name=run_name,
#     482     )
#     484 if log_system_metrics is None:
#     485     # If `log_system_metrics` is not specified, we will check environment variable.
#     486     log_system_metrics = MLFLOW_ENABLE_SYSTEM_METRICS_LOGGING.get()
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/tracking/client.py:479, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     425 def create_run(
#     426     self,
#     427     experiment_id: str,
#    (...)    430     run_name: str | None = None,
#     431 ) -> Run:
#     432     """
#     433     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     434     metrics, parameters, artifacts, etc.
#    (...)    477         status: RUNNING
#     478     """
# --> 479     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/telemetry/track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:183, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     178 # Extract user from tags
#     179 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     180 # in a later release.
#     181 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 183 return self.store.create_run(
#     184     experiment_id=experiment_id,
#     185     user_id=user_id,
#     186     start_time=start_time or get_current_time_millis(),
#     187     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     188     run_name=run_name,
#     189 )
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:340, in RestStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     330 tag_protos = [tag.to_proto() for tag in tags]
#     331 req_body = message_to_json(
#     332     CreateRun(
#     333         experiment_id=str(experiment_id),
#    (...)    338     )
#     339 )
# --> 340 response_proto = self._call_endpoint(CreateRun, req_body)
#     341 return Run.from_proto(response_proto.run)
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:203, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     201     endpoint, method = self._METHOD_TO_INFO[api]
#     202 response_proto = response_proto or api.Response()
# --> 203 return call_endpoint(
#     204     self.get_host_creds(),
#     205     endpoint,
#     206     method,
#     207     json_body,
#     208     response_proto,
#     209     retry_timeout_seconds=retry_timeout_seconds,
#     210 )
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File ~/work/benchmark_spatial_interpolation/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:321, in verify_rest_response(response, endpoint)
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
# --> 321         raise MlflowException(
#     322             f"{base_msg}. Response body: '{response.text}'",
#     323             error_code=get_error_code(response.status_code),
#     324         )
#     326 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     327 # response
#     328 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/runs/create failed with error code 401 != 200. Response body: 'You are not authenticated. Please see https://www.mlflow.org/docs/latest/auth/index.html#authenticating-to-mlflow on how to authenticate.'

# %% [markdown]
# Let's now evaluate our model on the test dataset

# %%
# Start an evaluation run
with mlflow.start_run() as evaluation_run:
    # Load our previous model
    logged_model = mlflow.sklearn.load_model(f"models:/{model_info.model_id}")

    # Evaluate the model on the training dataset and log metrics
    predictions = logged_model.predict(test_x)
    (rmse, mae, r2) = compute_metrics(test_y, predictions)
    mlflow.log_metrics(
        metrics={
            "rmse": rmse,
            "r2": r2,
            "mae": mae,
        },
        dataset=test_dataset,
        model_id=model_info.model_id,
    )

# %% [markdown]
# ## View results
#
# Let's look at our training and testing results. Log in to your Databricks Workspace, and click on the `Experiments` tab from the left menu. The initial page displays a list of runs, where we can see our training and evaluation runs.
#
# ![runs page](https://imgur.com/xtIRa9P.png)

# %% [markdown]
# Now let's head to the models tab, where we can see the model that we logged
#
# ![models page](https://imgur.com/hapuVHr.png)

# %% [markdown]
# Clicking on the model name will take you to the model details page, with information on its parameters, metrics across both runs, and other metadata.
#
# ![model details page](https://imgur.com/dAXNEWV.png)

# %% [markdown]
# We can also inspect our model using the API

# %%
logged_model = mlflow.get_logged_model(model_info.model_id)

logged_model, logged_model.metrics, logged_model.params
